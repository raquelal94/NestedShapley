# %% [markdown]
# The following jupyter notebook contains the computation for the stratified expected value included in the appendix example in the paper Alonso et al.
# Note that the model used for the characteristic function is modified to fit the requirements in the stratified expected value where the considered agents in each stratum has different battery capacities than agent $i$. This is the only difference with the model used for the Nested Shapley values.
#
# The stratified expected method is presented in
#
# Cremers, S., Robu, V., Zhang, P., Andoni, M., Norbu, S., & Flynn, D. (2023). Efficient methods for approximating the Shapley value for asset sharing in energy communities. Applied Energy, 331, 120328. https://doi.org/https://doi.org/10.1016/j.apenergy.2022.120328

# %%
import numpy as np
import os
import pandas as pd
import pytz
from src.ClusteringAlgorithm import GenerateArray
from src.appendix_model import model_p2p_stratified

# %%
# Directory with data
current_directory = os.path.normpath(os.path.join(os.getcwd(), ".."))
file_path_data = os.path.join(current_directory,r"data_appendix")

# Input data
start_date_str = "2019-6-11"
end_date_str = "2019-6-12"

N=12 # number of agents
np.random.seed(42)  # You can choose any number as a seed
houses_pv = np.random.choice(range(1, N + 1), int(N/2+2), replace=False)
houses_pv = [f"{i}" for i in houses_pv]
n_houses_pv = len(houses_pv)
PV_average = (n_houses_pv * 5) / N # calculate the average solar capacity

houses_bat = ['12', '10', '8', '9']
n_houses_bat = len(houses_bat)
S_average = (n_houses_bat * 4) / N # calculate the average storage capacity

# %% [markdown]
# Import and preprocess the demand data

# %%
def import_demand(file_demand,N):
    date_format_str = '%Y-%m-%d %H:%M:%S%z'  # '2019-12-06 14:00:00+00:00' format
    demand = pd.read_csv(file_demand, index_col=0,
                         parse_dates=[0], date_format=date_format_str)

    utc_tz = pytz.UTC  # just used to ensure matching the dates with the index
    start_date = pd.to_datetime(start_date_str, format='%Y-%m-%d').tz_localize(utc_tz)
    end_date = pd.to_datetime(end_date_str, format='%Y-%m-%d').tz_localize(utc_tz)
    demand.index = demand.index.to_pydatetime()
    demand = demand[demand.columns[:N]]
    demand = demand[(demand.index >= start_date) & (demand.index < end_date)]
    
    return demand
    
file_demand = os.path.join(file_path_data,"demand_Jan_365days.csv")
demand = import_demand(file_demand,N)

# %% [markdown]
# Functions

# %%
def generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand, current_agents, S_average=None, PV_average=None, house_bat_bool=None, house_pv_bool=None):
    # Case decentralised
    list_houses = current_agents.copy()
    if house_pv_bool is True:
        if "i" in list_houses:
            list_houses_pv = list_houses
            capacity_pv = list(np.full(len(list_houses_pv[:-1]), PV_average))
            capacity_pv.append(5) # todo: convert to variable
        else:
            list_houses_pv = list_houses
            capacity_pv = list(np.full(len(list_houses_pv), PV_average))
    else:
        if "i" in list_houses:
            list_houses_pv = list_houses[:-1]
            capacity_pv = list(np.full(len(list_houses_pv), PV_average))
        else:
            list_houses_pv = list_houses
            capacity_pv = list(np.full(len(list_houses_pv), PV_average))

    if house_bat_bool is True:
        if "i" in list_houses:
            list_houses_bat = list_houses
        else:
            list_houses_bat = list_houses
    else:
        if "i" in list_houses:
            list_houses_bat = list_houses[:-1]
        else:
            list_houses_bat = list_houses

    # transforming dates to align with data
    utc_tz = pytz.UTC  # just used to ensure matching the dates with the index
    start_date = pd.to_datetime(start_date_str, format='%Y-%m-%d').tz_localize(utc_tz)
    end_date = pd.to_datetime(end_date_str, format='%Y-%m-%d').tz_localize(utc_tz)

    # Get spot prices
    file_path = os.path.join(file_path_data, r"dayahead_Jan_365days.csv")
    date_format_str = '%Y-%m-%d %H:%M:%S%z'  # '2019-12-06 14:00:00+00:00' format
    P_spot_df = pd.read_csv(file_path, index_col=0,
                            parse_dates=[0], date_format=date_format_str)  # to make sure the date is read properly
    P_spot_df.index = P_spot_df.index.to_pydatetime() # convert to a datetime format required for the model
    P_spot_df = P_spot_df[["day ahead price (p/kWh)"]]  # get only price in pences/kWh
    P_spot_df_ = P_spot_df[(P_spot_df.index >= start_date) & (P_spot_df.index < end_date)]
    # Convert the dataframe P_spot_df_ to dictionary for data input for the function model_p2p()
    P_spot = P_spot_df_.to_dict()

    # Get demand
    demand_ = demand.stack()  # Set time and household as index
    # Convert the dataframe to dictionary
    P_demand = demand_.to_dict()

    # Get solar profiles, we assume the PV profile is the same for each house given that they are located close to each other
    file_path = os.path.join(file_path_data, r"solar_profile_scenarios_yearly.csv")
    PV_df = pd.read_csv(file_path, index_col=0,
                        parse_dates=[0], date_format=date_format_str)
    PV_df.index = PV_df.index.to_pydatetime() # convert to a datetime format required for the model
    scn = "1"
    PV_df = PV_df[[scn]]  # Select just one scenario, the data is prepared for several scenarios
    PV_df_ = PV_df[(PV_df.index >= start_date) & (PV_df.index < end_date)]
    # Convert the dataframe to dictionary
    PV = PV_df_.to_dict()

    # Set T
    list_T = P_spot_df_.index.to_list()

    # Parameter PV_cap
    PV_cap = {f"{key}":capacity_pv[i] for i, key in enumerate(list_houses_pv)}

    # Scalars (single value parameters)
    Psi = 1 - 0.076  # Losses (assume a loss of 7.6% through the local network, Luth)
    Mu_c = 0.96  # Charging efficiency
    Mu_d = 0.96  # Discharging efficiency

    # Case with shared resources
    #Smax = 4  # capacity batteries [kWh] # It can also be changes to be similar to parameter PV_cap where you specify the capacity of each battery
    # Case with no shared resources
    Smax = S_average
    Alpha = S_average * 1.5/4  # charging rate 2.5 kW -> 1.25 kWh/hour at constant rate
    Beta =  S_average * 1.5/4  # discharging rate 2.5 kW -> 1.25 kWh/hour at constant rate
    Smin = Smax * 0.2  # minimum state of charge of batteries at all times
    S_init = Smax * 0.5  # initial state of charge of the battery

    if "i" in list_houses_bat:
        Smax_dict = {agent: Smax for agent in list_houses_bat[:-1]}
        Alpha_dict = {agent: Alpha for agent in list_houses_bat[:-1]}
        Beta_dict = Alpha_dict.copy()
        Smin_dict = {agent: Smin for agent in list_houses_bat[:-1]}
        Sinit_dict = {agent: S_init for agent in list_houses_bat[:-1]}

        Smax_dict["i"] = 4 # add the battery capacity of the agent i mannually if it corresponds to the houses with batteries
        Alpha_dict["i"] = 1.5
        Beta_dict["i"] = 1.5
        Smin_dict["i"] = 4 * 0.2
        Sinit_dict["i"] = 4 * 0.5
    else:
        Smax_dict = {agent: Smax for agent in list_houses_bat}
        Alpha_dict = {agent: Alpha for agent in list_houses_bat}
        Beta_dict = Alpha_dict.copy()
        Smin_dict = {agent: Smin for agent in list_houses_bat}
        Sinit_dict = {agent: S_init for agent in list_houses_bat}

    c_FFR = 1000

    # Construct data dictionary
    data = {  # always start with None and then dictionary
        None: {  # names of the keys equal to the name of the parameteres in the model
            'H': {None: list_houses},  # providing data for set H
            'H_pv': {None: list_houses_pv},  # providing data for set H_pv
            "H_bat": {None: list_houses_bat},  # providing data for set H_bat
            "T": {None: list_T},  # providing datetime for set T
            # Parameters
            'P_spot': P_spot['day ahead price (p/kWh)'],
            "PV": PV[scn],
            "PV_cap": PV_cap,
            "Dem": P_demand,
            # Scalars
            "Psi": {None: Psi},
            "Mu_c": {None: Mu_c},
            "Mu_d": {None: Mu_d},
            "Alpha": Alpha_dict,
            "Beta": Beta_dict,
            "Smax": Smax_dict,
            "Smin": Smin_dict,
            "S_init": Sinit_dict,
            "c_FFR": {None: c_FFR}
        }}

    return data

# %% [markdown]
# ### Case 1: Different agent contribution

# %%
# Initialise matrix C to save the costs for different agents in different stratums
C = np.zeros((N, 2, N)) # strata, costs, agents

agents_list = [f"{i}" for i in demand.columns.tolist()] # list of agents

for i, agent in enumerate(agents_list): # For each agent
    house_bat_bool = False
    S_average = (n_houses_bat * 4) / (N)
    house_pv_bool = False
    PV_average = (n_houses_pv * 5) / (N)  # Included also in generation of data!

    # Calculate the average demand profile without agent i
    demand_average = demand.drop(agent, axis=1)
    demand_average = demand_average.mean(axis=1)

    if agent in houses_bat:
        house_bat_bool = True
        S_average = ((n_houses_bat - 1) * 4) / (N) # reduce the capacity of the rest of agents if the house has already capacity

    if agent in houses_pv:
        house_pv_bool = True
        PV_average = ((n_houses_pv - 1) * 5) / (N)  # reduce the capacity of the rest of agents if the house has already capacity

    for j in range(N): # Go through every stratum
        if j !=0: # Skip calculation of v(emptyset)
            print(f"\nAgent {agent} Stratum {j} Cost c(j)")
            # Calculate cost for S({1,...,j}) with average demand
            demand_stratum = pd.concat([demand_average] * j, axis=1)
            demand_stratum.columns = [f"{l}" for l in range(1, j+1)]
            current_agents = demand_stratum.columns.to_list()
            data_c_j = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool, house_pv_bool)
            instance_c_j = model_p2p_stratified(data_c_j)
            C[j, 0, i] = instance_c_j.objective_function.expr()

            # Calculate cost for S({1,...,j}) with average demand U {i}
            print(f"\nAgent {agent} Stratum {j} Cost c(jUi)")
            demand_stratum["i"] = demand[agent]
            current_agents.append("i")
            data_c_j_i = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool, house_pv_bool)
            instance_c_j_i = model_p2p_stratified(data_c_j_i)
            C[j, 1, i] = instance_c_j_i.objective_function.expr()
        else:
            print(f"\nAgent {agent} Stratum {j} Cost c(jUi) (Empty Set j)")
            # Calculate cost for S({1,...,j}) with average demand U {i}
            demand_stratum = demand[agent].to_frame()
            demand_stratum.columns = ["i"]
            current_agents = ["i"]

            data_c_j_i = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool, house_pv_bool)
            instance_c_j_i = model_p2p_stratified(data_c_j_i)
            C[j, 1, i] = instance_c_j_i.objective_function.expr()

# Activate to save the Cost Matrix, C
#C_2d = C.reshape(-1, C.shape[2]) # every 2 rows it identifies a stratum the first row is the c(j) and the second the c(jUi)
#np.savetxt(r"C_stratified.csv", C_2d, delimiter=",", fmt="%f")

# Calculate SEV_i
SEV_i = np.zeros(N)
for i, agent in enumerate(agents_list):
    c_j_i = C[:, 1, i]
    c_j = C[:, 0, i]

    sum_cost = 0
    for j in range(len(c_j)):
        sum_cost += c_j_i[j] - c_j[j]

    SEV_i[i] = 1/N * sum_cost
# Out:
# Agent 1 Stratum 0 Cost c(jUi) (Empty Set j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpke6wn91h.pyomo.lp
# Reading time = 0.00 seconds
# x242: 241 rows, 241 columns, 529 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 241 rows, 241 columns and 529 nonzeros
# Model fingerprint: 0xf16e481c
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-02, 1e+00]
# Presolve removed 241 rows and 241 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8348785e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.834878543e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x242
#   Lower bound: 18.34878543229052
#   Upper bound: 18.34878543229052
#   Number of objectives: 1
#   Number of constraints: 241
#   Number of variables: 241
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 241
#   Number of nonzeros: 529
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.0019989013671875
#   Error rc: 0
#   Time: 0.18387508392333984
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 1 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmp9p6m3b63.pyomo.lp
# Reading time = 0.00 seconds
# x482: 481 rows, 385 columns, 1008 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 481 rows, 385 columns and 1008 nonzeros
# Model fingerprint: 0x945953f2
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 394 rows and 211 columns
# Presolve time: 0.00s
# Presolved: 87 rows, 174 columns, 299 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.764369e+00   0.000000e+00      0s
#       60    1.9581940e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 60 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.958194000e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x482
#   Lower bound: 19.58193999912938
#   Upper bound: 19.58193999912938
#   Number of objectives: 1
#   Number of constraints: 481
#   Number of variables: 385
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 385
#   Number of nonzeros: 1008
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.00299072265625
#   Error rc: 0
#   Time: 0.16350626945495605
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 1 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmptc3sf35t.pyomo.lp
# Reading time = 0.00 seconds
# x914: 769 rows, 817 columns, 1920 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 769 rows, 817 columns and 1920 nonzeros
# Model fingerprint: 0xe3aab8cd
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 625 rows and 505 columns
# Presolve time: 0.00s
# Presolved: 144 rows, 312 columns, 551 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.585729e+01   0.000000e+00      0s
#      115    3.3023253e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 115 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.302325316e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x914
#   Lower bound: 33.023253162218914
#   Upper bound: 33.023253162218914
#   Number of objectives: 1
#   Number of constraints: 769
#   Number of variables: 817
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 817
#   Number of nonzeros: 1920
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.00299835205078125
#   Error rc: 0
#   Time: 0.12507891654968262
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 2 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmphducz_8u.pyomo.lp
# Reading time = 0.00 seconds
# x1154: 1009 rows, 961 columns, 2399 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1009 rows, 961 columns and 2399 nonzeros
# Model fingerprint: 0x1a5fe8b9
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 817 rows and 490 columns
# Presolve time: 0.00s
# Presolved: 192 rows, 471 columns, 853 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.858750e+01   0.000000e+00      0s
#      189    3.9163880e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 189 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.916388000e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x1154
#   Lower bound: 39.16387999825876
#   Upper bound: 39.16387999825876
#   Number of objectives: 1
#   Number of constraints: 1009
#   Number of variables: 961
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 961
#   Number of nonzeros: 2399
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.0029926300048828125
#   Error rc: 0
#   Time: 0.13884425163269043
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 2 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmppfam6alc.pyomo.lp
# Reading time = 0.00 seconds
# x1778: 1393 rows, 1585 columns, 3695 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1393 rows, 1585 columns and 3695 nonzeros
# Model fingerprint: 0x32b81f63
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 1153 rows and 865 columns
# Presolve time: 0.00s
# Presolved: 240 rows, 720 columns, 1294 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.337795e+01   0.000000e+00      0s
#      262    5.2338160e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 262 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.233816013e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x1778
#   Lower bound: 52.33816013294394
#   Upper bound: 52.33816013294394
#   Number of objectives: 1
#   Number of constraints: 1393
#   Number of variables: 1585
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 1585
#   Number of nonzeros: 3695
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.0049896240234375
#   Error rc: 0
#   Time: 0.1380455493927002
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 3 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpi3uelz4x.pyomo.lp
# Reading time = 0.01 seconds
# x2018: 1633 rows, 1729 columns, 4174 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1633 rows, 1729 columns and 4174 nonzeros
# Model fingerprint: 0xb206bf1a
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 1345 rows and 865 columns
# Presolve time: 0.00s
# Presolved: 288 rows, 864 columns, 1581 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.262743e+01   0.000000e+00      0s
#      189    5.8745820e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       16 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.6645353e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      222    5.8745820e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 222 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.874582000e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x2018
#   Lower bound: 58.745819997388146
#   Upper bound: 58.745819997388146
#   Number of objectives: 1
#   Number of constraints: 1633
#   Number of variables: 1729
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 1729
#   Number of nonzeros: 4174
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.010431289672851562
#   Error rc: 0
#   Time: 0.16876220703125
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 3 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmplbvj6w7b.pyomo.lp
# Reading time = 0.01 seconds
# x2834: 2113 rows, 2545 columns, 5854 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2113 rows, 2545 columns and 5854 nonzeros
# Model fingerprint: 0xd2366a32
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 1777 rows and 1345 columns
# Presolve time: 0.00s
# Presolved: 336 rows, 1200 columns, 2205 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.241336e+01   0.000000e+00      0s
#      269    7.1707156e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       35 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.6645353e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      325    7.1707156e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 325 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  7.170715603e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x2834
#   Lower bound: 71.707156026506
#   Upper bound: 71.707156026506
#   Number of objectives: 1
#   Number of constraints: 2113
#   Number of variables: 2545
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 2545
#   Number of nonzeros: 5854
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.009929656982421875
#   Error rc: 0
#   Time: 0.15348410606384277
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 4 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpnez1trcx.pyomo.lp
# Reading time = 0.01 seconds
# x3074: 2353 rows, 2689 columns, 6333 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2353 rows, 2689 columns and 6333 nonzeros
# Model fingerprint: 0xa790cc1b
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 1969 rows and 1345 columns
# Presolve time: 0.00s
# Presolved: 384 rows, 1344 columns, 2492 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.269582e+01   0.000000e+00      0s
#      173    7.8327760e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       24 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.5527137e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      214    7.8327760e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 214 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  7.832776000e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x3074
#   Lower bound: 78.32775999651751
#   Upper bound: 78.32775999651751
#   Number of objectives: 1
#   Number of constraints: 2353
#   Number of variables: 2689
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 2689
#   Number of nonzeros: 6333
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.008783340454101562
#   Error rc: 0
#   Time: 0.16045165061950684
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 4 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpugq4sfgl.pyomo.lp
# Reading time = 0.01 seconds
# x4082: 2929 rows, 3697 columns, 8397 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2929 rows, 3697 columns and 8397 nonzeros
# Model fingerprint: 0xe5b14a8f
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 2497 rows and 1921 columns
# Presolve time: 0.00s
# Presolved: 432 rows, 1776 columns, 3308 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.581134e+01   0.000000e+00      0s
#      267    9.1076152e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       70 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.5527137e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      374    9.1076152e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 374 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.107615192e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x4082
#   Lower bound: 91.07615192006809
#   Upper bound: 91.07615192006809
#   Number of objectives: 1
#   Number of constraints: 2929
#   Number of variables: 3697
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 3697
#   Number of nonzeros: 8397
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.011892318725585938
#   Error rc: 0
#   Time: 0.17784333229064941
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 5 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmp7wtrcz1d.pyomo.lp
# Reading time = 0.01 seconds
# x4322: 3169 rows, 3841 columns, 8876 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3169 rows, 3841 columns and 8876 nonzeros
# Model fingerprint: 0x21926222
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 2689 rows and 1921 columns
# Presolve time: 0.01s
# Presolved: 480 rows, 1920 columns, 3595 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.165688e+01   0.000000e+00      0s
#      193    9.7909700e+01   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       34 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.4408921e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      254    9.7909700e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 254 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.790970000e+01
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x4322
#   Lower bound: 97.90969999564689
#   Upper bound: 97.90969999564689
#   Number of objectives: 1
#   Number of constraints: 3169
#   Number of variables: 3841
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 3841
#   Number of nonzeros: 8876
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.011945724487304688
#   Error rc: 0
#   Time: 0.17855024337768555
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 5 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpcpfeytdk.pyomo.lp
# Reading time = 0.02 seconds
# x5522: 3841 rows, 5041 columns, 11324 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3841 rows, 5041 columns and 11324 nonzeros
# Model fingerprint: 0x84fae59e
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 3313 rows and 2593 columns
# Presolve time: 0.01s
# Presolved: 528 rows, 2448 columns, 4603 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.989861e+01   0.000000e+00      0s
#      290    1.1044515e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       81 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.4408921e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      414    1.1044515e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 414 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.104451478e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x5522
#   Lower bound: 110.44514781363016
#   Upper bound: 110.44514781363016
#   Number of objectives: 1
#   Number of constraints: 3841
#   Number of variables: 5041
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 5041
#   Number of nonzeros: 11324
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.014791488647460938
#   Error rc: 0
#   Time: 0.1759483814239502
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 6 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmp6mm_bln8.pyomo.lp
# Reading time = 0.02 seconds
# x5762: 4081 rows, 5185 columns, 11803 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4081 rows, 5185 columns and 11803 nonzeros
# Model fingerprint: 0xddcc6d14
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 3505 rows and 2593 columns
# Presolve time: 0.01s
# Presolved: 576 rows, 2592 columns, 4890 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.169108e+01   0.000000e+00      0s
#      192    1.1749164e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       38 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.3290705e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      262    1.1749164e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 262 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.174916400e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x5762
#   Lower bound: 117.49163999477624
#   Upper bound: 117.49163999477624
#   Number of objectives: 1
#   Number of constraints: 4081
#   Number of variables: 5185
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 5185
#   Number of nonzeros: 11803
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.014255523681640625
#   Error rc: 0
#   Time: 0.1829519271850586
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 6 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpc7iz_vfq.pyomo.lp
# Reading time = 0.02 seconds
# x7154: 4849 rows, 6577 columns, 14635 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4849 rows, 6577 columns and 14635 nonzeros
# Model fingerprint: 0x88cf4574
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 4225 rows and 3361 columns
# Presolve time: 0.01s
# Presolved: 624 rows, 3216 columns, 6090 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.215632e+01   0.000000e+00      0s
#      260    1.2981414e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      118 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.3290705e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      432    1.2981414e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 432 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  1.298141437e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x7154
#   Lower bound: 129.8141437071923
#   Upper bound: 129.8141437071923
#   Number of objectives: 1
#   Number of constraints: 4849
#   Number of variables: 6577
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 6577
#   Number of nonzeros: 14635
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.017995834350585938
#   Error rc: 0
#   Time: 0.190476655960083
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 7 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmppx4v9uwe.pyomo.lp
# Reading time = 0.02 seconds
# x7394: 5089 rows, 6721 columns, 15114 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5089 rows, 6721 columns and 15114 nonzeros
# Model fingerprint: 0x7371731d
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 4417 rows and 3361 columns
# Presolve time: 0.01s
# Presolved: 672 rows, 3360 columns, 6377 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.172528e+01   0.000000e+00      0s
#      191    1.3707358e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       46 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.2172489e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      274    1.3707358e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 274 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  1.370735800e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x7394
#   Lower bound: 137.0735799939057
#   Upper bound: 137.0735799939057
#   Number of objectives: 1
#   Number of constraints: 5089
#   Number of variables: 6721
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 6721
#   Number of nonzeros: 15114
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.01657867431640625
#   Error rc: 0
#   Time: 0.2007145881652832
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 7 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpacka52ut.pyomo.lp
# Reading time = 0.02 seconds
# x8978: 5953 rows, 8305 columns, 18330 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5953 rows, 8305 columns and 18330 nonzeros
# Model fingerprint: 0xbc3b1e41
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 5233 rows and 4225 columns
# Presolve time: 0.01s
# Presolved: 720 rows, 4080 columns, 7769 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.148520e+01   0.000000e+00      0s
#      246    1.4918314e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      149 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.2172489e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      459    1.4918314e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 459 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.491831396e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x8978
#   Lower bound: 149.1831396007545
#   Upper bound: 149.1831396007545
#   Number of objectives: 1
#   Number of constraints: 5953
#   Number of variables: 8305
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 8305
#   Number of nonzeros: 18330
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.019191741943359375
#   Error rc: 0
#   Time: 0.21172189712524414
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 8 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpdsqd9c10.pyomo.lp
# Reading time = 0.02 seconds
# x9218: 6193 rows, 8449 columns, 18809 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6193 rows, 8449 columns and 18809 nonzeros
# Model fingerprint: 0x0f31e935
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 5425 rows and 4225 columns
# Presolve time: 0.01s
# Presolved: 768 rows, 4224 columns, 8056 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.175948e+01   0.000000e+00      0s
#      186    1.5665552e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       50 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.1054274e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      271    1.5665552e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 271 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.566555200e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x9218
#   Lower bound: 156.65551999303514
#   Upper bound: 156.65551999303514
#   Number of objectives: 1
#   Number of constraints: 6193
#   Number of variables: 8449
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 8449
#   Number of nonzeros: 18809
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.018541336059570312
#   Error rc: 0
#   Time: 0.2116250991821289
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 8 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpimhlx2zu.pyomo.lp
# Reading time = 0.03 seconds
# x10994: 7153 rows, 10225 columns, 22409 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7153 rows, 10225 columns and 22409 nonzeros
# Model fingerprint: 0xaefa33b2
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-03, 1e+00]
# Presolve removed 6337 rows and 5185 columns
# Presolve time: 0.01s
# Presolved: 816 rows, 5040 columns, 9640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.100583e+01   0.000000e+00      0s
#      230    1.6855214e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      181 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.1054274e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      476    1.6855214e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 476 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.685521355e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x10994
#   Lower bound: 168.5521354943166
#   Upper bound: 168.5521354943166
#   Number of objectives: 1
#   Number of constraints: 7153
#   Number of variables: 10225
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 10225
#   Number of nonzeros: 22409
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.02203369140625
#   Error rc: 0
#   Time: 0.2201681137084961
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 1 Stratum 9 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmp_sw322mt.pyomo.lp
# Reading time = 0.03 seconds
# x11234: 7393 rows, 10369 columns, 22888 nonzeros
# ...
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 1e+00]
# Presolve removed 7729 rows and 6241 columns
# Presolve time: 0.02s
# Presolved: 960 rows, 6240 columns, 11990 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.325860e+00   0.000000e+00      0s
#      181    1.7487425e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       56 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.8817842e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      269    1.7487425e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 269 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  1.748742495e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x13442
#   Lower bound: 174.8742494717215
#   Upper bound: 174.8742494717215
#   Number of objectives: 1
#   Number of constraints: 8689
#   Number of variables: 12481
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 12481
#   Number of nonzeros: 27351
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.029153823852539062
#   Error rc: 0
#   Time: 0.25275278091430664
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 12 Stratum 10 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpcrvszb16.pyomo.lp
# Reading time = 0.04 seconds
# x15842: 10081 rows, 14785 columns, 32198 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10081 rows, 14785 columns and 32198 nonzeros
# Model fingerprint: 0x0684c1ff
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 4e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 9025 rows and 7393 columns
# Presolve time: 0.03s
# Presolved: 1056 rows, 7392 columns, 14245 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.290e+02
#  Factor NZ  : 2.713e+03
#  Factor Ops : 2.923e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.04336189e+03 -3.87571148e+03  8.46e-01 0.00e+00  1.56e+01     0s
#    1   1.81246855e+03 -1.65289862e+03  1.97e-01 7.54e-02  3.22e+00     0s
#    2   4.99267511e+02 -2.86454566e+02  3.34e-02 1.42e-14  5.95e-01     0s
#    3   3.30087060e+02  9.46052216e+01  1.20e-02 1.42e-14  1.65e-01     0s
#    4   2.50278130e+02  1.67118201e+02  3.52e-03 1.42e-14  5.80e-02     0s
#    5   2.31811808e+02  1.92208612e+02  1.93e-03 1.42e-14  2.71e-02     0s
#    6   2.22417359e+02  2.00907364e+02  1.10e-03 1.42e-14  1.46e-02     0s
#    7   2.17560616e+02  2.06470646e+02  6.84e-04 1.42e-14  7.38e-03     0s
#    8   2.12704285e+02  2.08547604e+02  2.61e-04 1.42e-14  2.76e-03     0s
#    9   2.10434113e+02  2.09281503e+02  6.22e-05 1.42e-14  7.77e-04     0s
#   10   2.09704483e+02  2.09627784e+02  1.91e-06 2.84e-14  5.46e-05     0s
#   11   2.09667512e+02  2.09667434e+02  1.60e-14 2.84e-14  5.80e-08     0s
#   12   2.09667478e+02  2.09667478e+02  3.74e-14 2.84e-14  5.80e-11     0s
#   13   2.09667478e+02  2.09667478e+02  7.20e-14 1.42e-14  1.53e-16     0s
#
# Barrier solved model in 13 iterations and 0.04 seconds (0.03 work units)
# Optimal objective 2.09667478e+02
#
# Crossover log...
#
#      107 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      221 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7763568e-15      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      329    2.0966748e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      145 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0658141e-14      0s
#
#
# Solved with dual simplex
# Solved in 617 iterations and 0.04 seconds (0.03 work units)
# Optimal objective  2.096674777e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x15842_copy
#   Lower bound: 209.66747770046848
#   Upper bound: 209.66747770046848
#   Number of objectives: 1
#   Number of constraints: 10081
#   Number of variables: 14785
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 14785
#   Number of nonzeros: 32198
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.04578208923339844
#   Error rc: 0
#   Time: 0.2811465263366699
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 12 Stratum 11 Cost c(j)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmpo9_hdof5.pyomo.lp
# Reading time = 0.04 seconds
# x15842: 10081 rows, 14785 columns, 32198 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10081 rows, 14785 columns and 32198 nonzeros
# Model fingerprint: 0x889d6560
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 9025 rows and 7393 columns
# Presolve time: 0.03s
# Presolved: 1056 rows, 7392 columns, 14245 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.020e+02
#  Factor NZ  : 2.414e+03
#  Factor Ops : 4.817e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.57696861e+03 -1.59004730e+03  4.26e-01 0.00e+00  8.27e+00     0s
#    1   6.33908882e+02 -5.39615652e+02  1.33e-01 1.09e-01  2.04e+00     0s
#    2   3.11150310e+02 -4.51675604e+01  6.28e-02 1.42e-14  5.23e-01     0s
#    3   2.26316330e+02  1.51994677e+02  1.24e-02 1.42e-14  1.01e-01     0s
#    4   2.03978578e+02  1.79838937e+02  2.66e-03 1.42e-14  3.27e-02     0s
#    5   1.97947368e+02  1.88187886e+02  1.27e-03 1.42e-14  1.30e-02     0s
#    6   1.95478417e+02  1.90550593e+02  7.11e-04 1.42e-14  6.52e-03     0s
#    7   1.93998727e+02  1.91947342e+02  3.59e-04 1.42e-14  2.67e-03     0s
#    8   1.93155907e+02  1.92253781e+02  1.76e-04 1.42e-14  1.16e-03     0s
#    9   1.92588789e+02  1.92324359e+02  4.54e-05 1.42e-14  3.44e-04     0s
#   10   1.92365650e+02  1.92358717e+02  4.52e-14 1.42e-14  9.79e-06     0s
#   11   1.92361679e+02  1.92361663e+02  1.55e-14 1.42e-14  2.24e-08     0s
#   12   1.92361674e+02  1.92361674e+02  4.53e-13 7.99e-15  4.39e-14     0s
#
# Barrier solved model in 12 iterations and 0.03 seconds (0.02 work units)
# Optimal objective 1.92361674e+02
#
# Crossover log...
#
#       47 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       75 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1546319e-14      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      125    1.9236167e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Solved with dual simplex
# Solved in 291 iterations and 0.04 seconds (0.03 work units)
# Optimal objective  1.923616744e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x15842_copy
#   Lower bound: 192.3616744188937
#   Upper bound: 192.3616744188937
#   Number of objectives: 1
#   Number of constraints: 10081
#   Number of variables: 14785
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 14785
#   Number of nonzeros: 32198
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.04239082336425781
#   Error rc: 0
#   Time: 0.30135250091552734
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Agent 12 Stratum 11 Cost c(jUi)
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-08
# Read LP format model from file C:\Users\raquelal\AppData\Local\Temp\tmph4avxtcd.pyomo.lp
# Reading time = 0.05 seconds
# x18434: 11569 rows, 17281 columns, 37429 nonzeros
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11569 rows, 17281 columns and 37429 nonzeros
# Model fingerprint: 0xbdae0cfc
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+00]
#   Objective range  [3e+00, 5e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-02, 4e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 10417 rows and 8641 columns
# Presolve time: 0.03s
# Presolved: 1152 rows, 8640 columns, 16692 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.290e+02
#  Factor NZ  : 2.713e+03
#  Factor Ops : 2.923e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.34375220e+03 -3.95741002e+03  8.69e-01 0.00e+00  1.62e+01     0s
#    1   1.94521366e+03 -1.70385921e+03  2.06e-01 4.09e-02  3.39e+00     0s
#    2   5.51991666e+02 -3.23837544e+02  3.71e-02 1.42e-14  6.68e-01     0s
#    3   3.48945826e+02  9.07098677e+01  1.40e-02 2.84e-14  1.82e-01     0s
#    4   2.70548073e+02  1.79769800e+02  3.61e-03 1.42e-14  6.35e-02     0s
#    5   2.49540991e+02  2.04912783e+02  1.86e-03 1.42e-14  3.09e-02     0s
#    6   2.38012551e+02  2.17921820e+02  9.44e-04 1.42e-14  1.37e-02     0s
#    7   2.33504486e+02  2.22464893e+02  5.82e-04 1.42e-14  7.46e-03     0s
#    8   2.29485842e+02  2.25493215e+02  2.50e-04 1.42e-14  2.64e-03     0s
#    9   2.27217349e+02  2.26141766e+02  6.62e-05 1.42e-14  7.13e-04     0s
#   10   2.26413663e+02  2.26362745e+02  1.83e-06 1.42e-14  3.55e-05     0s
#   11   2.26382246e+02  2.26382123e+02  2.28e-10 2.84e-14  9.11e-08     0s
#   12   2.26382196e+02  2.26382196e+02  2.11e-12 1.47e-14  9.11e-11     0s
#   13   2.26382196e+02  2.26382196e+02  2.80e-12 1.42e-14  1.77e-16     0s
#
# Barrier solved model in 13 iterations and 0.04 seconds (0.03 work units)
# Optimal objective 2.26382196e+02
#
# Crossover log...
#
#      108 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      228 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.8230787e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      336    2.2638220e+02   0.000000e+00   2.823079e+00      0s
#      338    2.2638220e+02   0.000000e+00   0.000000e+00      0s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Solved with dual simplex
# Solved in 656 iterations and 0.05 seconds (0.03 work units)
# Optimal objective  2.263821958e+02
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: x18434_copy
#   Lower bound: 226.38219583139062
#   Upper bound: 226.38219583139062
#   Number of objectives: 1
#   Number of constraints: 11569
#   Number of variables: 17281
#   Number of binary variables: 0
#   Number of integer variables: 0
#   Number of continuous variables: 17281
#   Number of nonzeros: 37429
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Return code: 0
#   Message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Termination condition: optimal
#   Termination message: Model was solved to optimality (subject to tolerances), and an optimal solution is available.
#   Wall time: 0.05059623718261719
#   Error rc: 0
#   Time: 0.30712175369262695
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %% [markdown]
# Now, we need to normalise it to the real characteristic function of the entire coalition. This value was calculated from the cases in `appendix_nestedshapley.ipynb`

# %%
c_N = 272.940594

# %%
total_SEV_i = np.sum(SEV_i)
SEV = np.zeros(len(SEV_i))
for i in range(len(SEV_i)):
    SEV[i] = SEV_i[i]*c_N/total_SEV_i

# %%
print("The stratified expected values of the agents are: \n")
for i, agent in enumerate(agents_list):
    print(f"Agent {agent}: {SEV[i].round(1)}")
# Out:
# The stratified expected values of the agents are:
#
# Agent 1: 12.4
# Agent 2: 8.4
# Agent 3: 32.4
# Agent 4: 45.1
# Agent 5: 20.8
# Agent 6: 13.6
# Agent 7: 10.7
# Agent 8: 13.7
# Agent 9: 5.8
# Agent 10: 31.2
# Agent 11: 41.1
# Agent 12: 37.8

# %% [markdown]
# ### Case 2: Equal agent contribution

# %%
# Initialise matrix C to save the costs for different agents in different stratums
C = np.zeros((N, 2, N)) # strata, costs, agents

agents_list = [f"{i}" for i in demand.columns.tolist()] # list of agents

for i, agent in enumerate(agents_list): # For each agent
    S_average = 4 # they all have 4 kWh
    PV_average = 5 # They all have 5 kW

    # Calculate the average demand profile without agent i
    demand_average = demand.drop(agent, axis=1)
    demand_average = demand_average.mean(axis=1)

    for j in range(N): # Go through every stratum
        if j !=0: # Skip calculation of v(emptyset)
            print(f"\nAgent {agent} Stratum {j} Cost c(j)")
            # Calculate cost for S({1,...,j}) with average demand
            demand_stratum = pd.concat([demand_average] * j, axis=1)
            demand_stratum.columns = [f"{l}" for l in range(1, j+1)]
            current_agents = demand_stratum.columns.to_list()
            data_c_j = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool=None, house_pv_bool=None)
            instance_c_j = model_p2p_stratified(data_c_j)
            C[j, 0, i] = instance_c_j.objective_function.expr()

            # Calculate cost for S({1,...,j}) with average demand U {i}
            print(f"\nAgent {agent} Stratum {j} Cost c(jUi)")
            demand_stratum["i"] = demand[agent]
            current_agents.append("i")
            data_c_j_i = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool=None, house_pv_bool=None)
            instance_c_j_i = model_p2p_stratified(data_c_j_i)
            C[j, 1, i] = instance_c_j_i.objective_function.expr()
        else:
            print(f"\nAgent {agent} Stratum {j} Cost c(jUi) (Empty Set j)")
            # Calculate cost for S({1,...,j}) with average demand U {i}
            demand_stratum = demand[agent].to_frame()
            demand_stratum.columns = ["i"]
            current_agents = ["i"]

            data_c_j_i = generate_data_dict_stratified(file_path_data, start_date_str, end_date_str, demand_stratum, current_agents, S_average, PV_average, house_bat_bool=None, house_pv_bool=None)
            instance_c_j_i = model_p2p_stratified(data_c_j_i)
            C[j, 1, i] = instance_c_j_i.objective_function.expr()

# Activate to save the Cost Matrix, C
#C_2d = C.reshape(-1, C.shape[2]) # every 2 rows it identifies a stratum the first row is the c(j) and the second the c(jUi)
#np.savetxt(r"C_stratified.csv", C_2d, delimiter=",", fmt="%f")

# Calculate SEV_i
SEV_i = np.zeros(N)
for i, agent in enumerate(agents_list):
    c_j_i = C[:, 1, i]
    c_j = C[:, 0, i]

    sum_cost = 0
    for j in range(len(c_j)):
        sum_cost += c_j_i[j] - c_j[j]

    SEV_i[i] = 1/N * sum_cost
